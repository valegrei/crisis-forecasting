# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.seasonal import STL

# %%
def graficar(s: pd.Series, t, resc = None, linea_cero=False):
    fig, ax = plt.subplots(figsize=[8,4])
    s.plot(ax=ax)
    ax.set_title(t)
    if resc is not None:        
        y1, y2 = ax.get_ylim()
        resc1 = resc == 1
        ax.fill_between(resc1.index, y1=y1, y2=y2, where=resc1, facecolor='grey', alpha=0.4)
    if linea_cero:
        ax.axhline(y=0,color='grey',linestyle='--')

def graficar2(s1: pd.Series, t1,s2: pd.Series, t2, linea_cero=False):
    fig, ax = plt.subplots(1,2,figsize=[10,4])
    s1.plot(ax=ax[0])
    s2.plot(ax=ax[1])
    ax[0].set_title(t1)
    ax[1].set_title(t2)
    if linea_cero:
        ax[0].axhline(y=0,color='grey',linestyle='--')
        ax[1].axhline(y=0,color='grey',linestyle='--')

def graficar_multiple(df):
    for col in df.columns:
        if col == 'Class':
            graficar(df[col], col)
            continue
        graficar(df[col],col,resc=df['Class'])

# %% [markdown]
# # Carga de datos
# Se extrayeron los datos de [Federal Reserve Bank of St. Louis](https://fred.stlouisfed.org/tags/series?t=monthly)

# %% [markdown]
# Indicadores Macroeconómicos

# %%
df = pd.read_csv('../data/USA_DATA.csv')
df['DATE'] = pd.to_datetime(df['DATE'])
df = df.set_index('DATE')
df['NBER'] = df['NBER'].astype('int')
df = df.rename(columns={'NBER':'Class'})
df.head()
# Out:
#             CPIAUCNS  FEDFUNDS   INDPRO  MPRIME   PAYEMS  TOTALSA  UNRATENSA  \
# DATE
# 1976-11-01      58.0      4.95  45.3540    6.50  80240.0   13.332        7.4
# 1976-12-01      58.2      4.65  45.8357    6.35  80448.0   14.527        7.4
# 1977-01-01      58.5      4.61  45.5276    6.25  80690.0   14.396        8.3
# 1977-02-01      59.1      4.68  46.2567    6.25  80988.0   14.709        8.5
# 1977-03-01      59.5      4.69  46.8356    6.25  81391.0   15.170        7.9
#
#             Class
# DATE
# 1976-11-01      0
# 1976-12-01      0
# 1977-01-01      0
# 1977-02-01      0
# 1977-03-01      0

# %% [markdown]
# # Descripción

# %% [markdown]
# Características de dataset de macroeconomia

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 553 entries, 1976-11-01 to 2022-11-01
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CPIAUCNS   553 non-null    float64
#  1   FEDFUNDS   553 non-null    float64
#  2   INDPRO     553 non-null    float64
#  3   MPRIME     553 non-null    float64
#  4   PAYEMS     553 non-null    float64
#  5   TOTALSA    553 non-null    float64
#  6   UNRATENSA  553 non-null    float64
#  7   Class      553 non-null    int32
# dtypes: float64(7), int32(1)
# memory usage: 36.7 KB

# %% [markdown]
# Metadatos del dataset

# %%
md = pd.read_csv('../data/USA_METADATA.csv')
md
# Out:
#      Feature                                        Description  \
# 0   CPIAUCNS  Consumer Price Index for All Urban Consumers: ...
# 1   FEDFUNDS                       Federal Funds Effective Rate
# 2     INDPRO                 Industrial Production: Total Index
# 3     MPRIME                               Bank Prime Loan Rate
# 4     PAYEMS                       All Employees, Total Nonfarm
# 5    TOTALSA                                Total Vehicle Sales
# 6  UNRATENSA                                  Unemployment Rate
# 7       NBER  NBER based Recession Indicators for the United...
#
#                                                 Unit
# 0       Index 1982-1984=100, Not Seasonally Adjusted
# 1                   Percent, Not Seasonally Adjusted
# 2                Index 2017=100, Seasonally Adjusted
# 3                   Percent, Not Seasonally Adjusted
# 4          Thousands of Persons, Seasonally Adjusted
# 5  Millions of Units, Seasonally Adjusted Annual ...
# 6                   Percent, Not Seasonally Adjusted
# 7                   +1 or 0, Not Seasonally Adjusted

# %% [markdown]
# Estadisticas descriptivas del dataset

# %%
df.describe()
# Out:
#          CPIAUCNS    FEDFUNDS      INDPRO      MPRIME         PAYEMS  \
# count  553.000000  553.000000  553.000000  553.000000     553.000000
# mean   170.529465    4.644774   79.158300    7.291863  120970.696203
# std     60.791453    4.072702   19.869044    3.657516   20144.376327
# min     58.000000    0.050000   45.354000    3.250000   80240.000000
# 25%    117.500000    1.010000   60.779000    4.000000  104962.000000
# 50%    168.300000    4.680000   87.548800    7.250000  129788.000000
# 75%    225.672000    6.790000   98.199000    9.000000  136325.000000
# max    298.012000   19.100000  104.812900   20.500000  153548.000000
#
#           TOTALSA   UNRATENSA       Class
# count  553.000000  553.000000  553.000000
# mean    15.166392    6.184448    0.115732
# std      2.273287    1.758471    0.320193
# min      8.923000    3.300000    0.000000
# 25%     13.798000    4.900000    0.000000
# 50%     15.452000    5.900000    0.000000
# 75%     16.960000    7.200000    0.000000
# max     22.055000   14.400000    1.000000

# %% [markdown]
# Grafica de las caracteristicas

# %%
graficar_multiple(df)

# %% [markdown]
# # Preprocesamiento

# %% [markdown]
# ## Ajuste Estacional

# %% [markdown]
# Segun lo anterior, se observa que TOTALSA y UNRATENSA presentan estacionalidad.
# Se procede a realizar un ajuste estacional, descomponiendo la serie y eliminando
# su componente de estacionalidad.

# %%
for col in df.columns:
    if col == 'Class':
        continue
    res = STL(df[col], period = 12).fit()
    df[col] = res.trend

# %% [markdown]
# Resultados

# %%
graficar_multiple(df)

# %% [markdown]
# ## Transformaciones

# %% [markdown]
# Se transforma las series a variaciones segun la observacion anterior usando diferencia logaritmica

# %%
df_diff = df.copy()
for col in df_diff.columns:
    if col == 'Class':
        continue
    df_diff[col] = np.log(df_diff[col]) - np.log(df_diff[col].shift(1))

# %%
graficar_multiple(df_diff)

# %% [markdown]
# Completar datos interpolando

# %%
df_diff.head()
# Out:
#             CPIAUCNS  FEDFUNDS    INDPRO    MPRIME    PAYEMS   TOTALSA  \
# DATE
# 1976-11-01       NaN       NaN       NaN       NaN       NaN       NaN
# 1976-12-01  0.005668  0.030362  0.004353  0.020660  0.004096  0.001506
# 1977-01-01  0.005636  0.029379  0.004318  0.020079  0.004089  0.001554
# 1977-02-01  0.005606  0.028482  0.004290  0.019538  0.004083  0.001644
# 1977-03-01  0.005580  0.027671  0.004267  0.019047  0.004076  0.001756
#
#             UNRATENSA  Class
# DATE
# 1976-11-01        NaN      0
# 1976-12-01  -0.012850      0
# 1977-01-01  -0.013024      0
# 1977-02-01  -0.013187      0
# 1977-03-01  -0.013338      0

# %%
df_diff.describe()
# Out:
#          CPIAUCNS    FEDFUNDS      INDPRO      MPRIME      PAYEMS  \
# count  552.000000  552.000000  552.000000  552.000000  552.000000
# mean     0.002980   -0.001091    0.001504   -0.000092    0.001188
# std      0.002182    0.071405    0.003272    0.018738    0.001763
# min     -0.000779   -0.287719   -0.012309   -0.051722   -0.006452
# 25%      0.001592   -0.026646    0.000322   -0.009446    0.000509
# 50%      0.002398    0.001627    0.002075    0.000082    0.001442
# 75%      0.003461    0.028067    0.003471    0.013065    0.002111
# max      0.011087    0.414850    0.008630    0.048879    0.004349
#
#             TOTALSA   UNRATENSA       Class
# count  5.520000e+02  552.000000  553.000000
# mean  -6.503275e-07   -0.001758    0.115732
# std    8.059840e-03    0.017313    0.320193
# min   -3.474568e-02   -0.054615    0.000000
# 25%   -3.181993e-03   -0.009246    0.000000
# 50%    7.457537e-04   -0.005265    0.000000
# 75%    5.037476e-03    0.003765    0.000000
# max    1.919342e-02    0.096487    1.000000

# %%
df_diff.drop(labels=['Class'],axis=1).plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
df.hist(figsize=[12,10],bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'CPIAUCNS'}>,
#         <AxesSubplot:title={'center':'FEDFUNDS'}>,
#         <AxesSubplot:title={'center':'INDPRO'}>],
#        [<AxesSubplot:title={'center':'MPRIME'}>,
#         <AxesSubplot:title={'center':'PAYEMS'}>,
#         <AxesSubplot:title={'center':'TOTALSA'}>],
#        [<AxesSubplot:title={'center':'UNRATENSA'}>,
#         <AxesSubplot:title={'center':'Class'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
df_diff.hist(figsize=[12,10], bins=20)
# Out:
# array([[<AxesSubplot:title={'center':'CPIAUCNS'}>,
#         <AxesSubplot:title={'center':'FEDFUNDS'}>,
#         <AxesSubplot:title={'center':'INDPRO'}>],
#        [<AxesSubplot:title={'center':'MPRIME'}>,
#         <AxesSubplot:title={'center':'PAYEMS'}>,
#         <AxesSubplot:title={'center':'TOTALSA'}>],
#        [<AxesSubplot:title={'center':'UNRATENSA'}>,
#         <AxesSubplot:title={'center':'Class'}>, <AxesSubplot:>]],
#       dtype=object)
