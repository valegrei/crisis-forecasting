# %%
import pandas as pd

# %%
df = pd.read_csv('modelamiento/modelos/MLP_TL_PERU_1_20221230_1644.csv')
print(df['prc'].argmax())
df
# Out:
# 0
#         loss   tp    fp    tn   fn  accuracy  precision  recall       auc  \
# 0   0.804313  3.0  17.0  66.0  0.0  0.802326       0.15     1.0  0.975904
# 1   0.883332  3.0  17.0  66.0  0.0  0.802326       0.15     1.0  0.969880
# 2   0.800538  3.0  17.0  66.0  0.0  0.802326       0.15     1.0  0.975904
# 3   0.871645  3.0  17.0  66.0  0.0  0.802326       0.15     1.0  0.969880
# 4   0.885354  3.0  17.0  66.0  0.0  0.802326       0.15     1.0  0.969880
# 5   0.802151  3.0  17.0  66.0  0.0  0.802326       0.15     1.0  0.975904
# 6   0.876481  3.0  17.0  66.0  0.0  0.802326       0.15     1.0  0.969880
# 7   0.804923  3.0  17.0  66.0  0.0  0.802326       0.15     1.0  0.975904
# 8   0.796087  3.0  17.0  66.0  0.0  0.802326       0.15     1.0  0.975904
# 9   0.877175  3.0  17.0  66.0  0.0  0.802326       0.15     1.0  0.969880
# 10  0.881277  3.0  17.0  66.0  0.0  0.802326       0.15     1.0  0.969880
# 11  0.869576  3.0  17.0  66.0  0.0  0.802326       0.15     1.0  0.969880
# ...
