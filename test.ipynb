# %%
import pandas as pd

# %%
df = pd.read_csv('modelamiento/modelos/CNN_USA_12_20221230_1717.csv')
print(df['prc'].argmax())
df
# Out:
# 8
#         loss   tp    fp    tn   fn  accuracy  precision  recall       auc  \
# 0   0.687407  3.0  34.0  54.0  0.0  0.626374   0.081081     1.0  0.619318
# 1   0.687307  3.0  35.0  53.0  0.0  0.615385   0.078947     1.0  0.626894
# 2   0.685792  3.0  37.0  51.0  0.0  0.593407   0.075000     1.0  0.621212
# 3   0.684708  3.0  37.0  51.0  0.0  0.593407   0.075000     1.0  0.628788
# 4   0.683563  3.0  37.0  51.0  0.0  0.593407   0.075000     1.0  0.615530
# 5   0.682245  3.0  37.0  51.0  0.0  0.593407   0.075000     1.0  0.626894
# 6   0.681635  3.0  38.0  50.0  0.0  0.582418   0.073171     1.0  0.642045
# 7   0.680736  3.0  38.0  50.0  0.0  0.582418   0.073171     1.0  0.625000
# 8   0.679112  3.0  40.0  48.0  0.0  0.560440   0.069767     1.0  0.657197
# 9   0.676885  3.0  41.0  47.0  0.0  0.549451   0.068182     1.0  0.643939
# 10  0.675299  3.0  39.0  49.0  0.0  0.571429   0.071429     1.0  0.653409
# 11  0.677120  3.0  39.0  49.0  0.0  0.571429   0.071429     1.0  0.653409
# ...
