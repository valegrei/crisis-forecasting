# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.seasonal import STL

# %%
def graficar(s: pd.Series, t, linea_cero=False):
    fig, ax = plt.subplots(figsize=[8,4])
    s.plot(ax=ax)
    ax.set_title(t)
    if linea_cero:
        ax.axhline(y=0,color='grey',linestyle='--')

def graficar2(s1: pd.Series, t1,s2: pd.Series, t2, linea_cero=False):
    fig, ax = plt.subplots(1,2,figsize=[10,4])
    s1.plot(ax=ax[0])
    s2.plot(ax=ax[1])
    ax[0].set_title(t1)
    ax[1].set_title(t2)
    if linea_cero:
        ax[0].axhline(y=0,color='grey',linestyle='--')
        ax[1].axhline(y=0,color='grey',linestyle='--')

# %% [markdown]
# # Carga de datos
# Se extrayeron los datos de [Federal Reserve Bank of St. Louis](https://fred.stlouisfed.org/tags/series?t=monthly)

# %% [markdown]
# Indicadores Macroeconómicos

# %%
df = pd.read_csv('../data/USA_DATA.csv')
df['DATE'] = pd.to_datetime(df['DATE'])
df = df.set_index('DATE')
df['NBER'] = df['NBER'].astype('int')
df.head()
# Out:
#             CPIAUCNS  FEDFUNDS   INDPRO  MPRIME   PAYEMS  TOTALSA  UNRATENSA  \
# DATE
# 1976-11-01      58.0      4.95  45.3540    6.50  80240.0   13.332        7.4
# 1976-12-01      58.2      4.65  45.8357    6.35  80448.0   14.527        7.4
# 1977-01-01      58.5      4.61  45.5276    6.25  80690.0   14.396        8.3
# 1977-02-01      59.1      4.68  46.2567    6.25  80988.0   14.709        8.5
# 1977-03-01      59.5      4.69  46.8356    6.25  81391.0   15.170        7.9
#
#             NBER
# DATE
# 1976-11-01     0
# 1976-12-01     0
# 1977-01-01     0
# 1977-02-01     0
# 1977-03-01     0

# %% [markdown]
# # Descripción

# %% [markdown]
# Características de dataset de macroeconomia

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 553 entries, 1976-11-01 to 2022-11-01
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   CPIAUCNS   553 non-null    float64
#  1   FEDFUNDS   553 non-null    float64
#  2   INDPRO     553 non-null    float64
#  3   MPRIME     553 non-null    float64
#  4   PAYEMS     553 non-null    float64
#  5   TOTALSA    553 non-null    float64
#  6   UNRATENSA  553 non-null    float64
#  7   NBER       553 non-null    int32
# dtypes: float64(7), int32(1)
# memory usage: 36.7 KB

# %% [markdown]
# Metadatos del dataset

# %%
md = pd.read_csv('../data/USA_METADATA.csv')
md
# Out:
#      Feature                                        Description  \
# 0   CPIAUCNS  Consumer Price Index for All Urban Consumers: ...
# 1   FEDFUNDS                       Federal Funds Effective Rate
# 2     INDPRO                 Industrial Production: Total Index
# 3     MPRIME                               Bank Prime Loan Rate
# 4     PAYEMS                       All Employees, Total Nonfarm
# 5    TOTALSA                                Total Vehicle Sales
# 6  UNRATENSA                                  Unemployment Rate
# 7       NBER  NBER based Recession Indicators for the United...
#
#                                                 Unit
# 0       Index 1982-1984=100, Not Seasonally Adjusted
# 1                   Percent, Not Seasonally Adjusted
# 2                Index 2017=100, Seasonally Adjusted
# 3                   Percent, Not Seasonally Adjusted
# 4          Thousands of Persons, Seasonally Adjusted
# 5  Millions of Units, Seasonally Adjusted Annual ...
# 6                   Percent, Not Seasonally Adjusted
# 7                   +1 or 0, Not Seasonally Adjusted

# %% [markdown]
# Estadisticas descriptivas del dataset

# %%
df.describe()
# Out:
#          CPIAUCNS    FEDFUNDS      INDPRO      MPRIME         PAYEMS  \
# count  553.000000  553.000000  553.000000  553.000000     553.000000
# mean   170.529465    4.644774   79.158300    7.291863  120970.696203
# std     60.791453    4.072702   19.869044    3.657516   20144.376327
# min     58.000000    0.050000   45.354000    3.250000   80240.000000
# 25%    117.500000    1.010000   60.779000    4.000000  104962.000000
# 50%    168.300000    4.680000   87.548800    7.250000  129788.000000
# 75%    225.672000    6.790000   98.199000    9.000000  136325.000000
# max    298.012000   19.100000  104.812900   20.500000  153548.000000
#
#           TOTALSA   UNRATENSA        NBER
# count  553.000000  553.000000  553.000000
# mean    15.166392    6.184448    0.115732
# std      2.273287    1.758471    0.320193
# min      8.923000    3.300000    0.000000
# 25%     13.798000    4.900000    0.000000
# 50%     15.452000    5.900000    0.000000
# 75%     16.960000    7.200000    0.000000
# max     22.055000   14.400000    1.000000

# %% [markdown]
# Grafica de las caracteristicas

# %%
for col in df.columns:
    graficar(df[col],col)

# %% [markdown]
# Segun lo anterior, se observa que TOTALSA y UNRATENSA presentan estacionalidad.
# Se procede a realizar un ajuste estacional, descomponiendo la serie y eliminando
# su componente de estacionalidad.

# %%
res = STL(df['CPIAUCNS'], period = 12).fit()
df['CPIAUCNS'] = res.trend
res = STL(df['FEDFUNDS'], period = 12).fit()
df['FEDFUNDS'] = res.trend
res = STL(df['INDPRO'], period = 12).fit()
df['INDPRO'] = res.trend
res = STL(df['MPRIME'], period = 12).fit()
df['MPRIME'] = res.trend
res = STL(df['TOTALSA'], period = 12).fit()
df['TOTALSA'] = res.trend
res = STL(df['UNRATENSA'], period = 12).fit()
df['UNRATENSA'] = res.trend

# %% [markdown]
# Resultados

# %%
for col in df.columns:
    graficar(df[col],col)

# %% [markdown]
# # Preprocesamiento

# %% [markdown]
# Completar datos interpolando

# %%
def preprocesar(df : pd.DataFrame, df2 : pd.DataFrame):
    paises = df.iso.unique()
    df_r = pd.DataFrame()
    for pais in paises:
        df_n = df[df.iso==pais].copy()
        #Fija year como indice
        df_n = df_n.astype({'year': np.int16})
        df_n = df_n.set_index('year')
        #interpola datos faltantes en la serie
        df_n = df_n.interpolate()
        #calcula el ratio de crecimiento del PBI real
        df_n['rgdp_growth'] = df_n['rgdp'].pct_change()*100.0
        df_n = df_n.drop('rgdp',axis=1)
        #calcula la inflacion a partir del cpi
        df_n['infl_cpi'] = df_n['cpi'].pct_change()*100.0
        df_n = df_n.drop('cpi',axis=1)
        #escala logaritmica
        #df_n['rgdp'] = np.log10(df_n['rgdp'])
        #df_n['cpi'] = np.log10(df_n['cpi'])
        #Une con el data frame 2
        df_n = pd.merge(left=df_n, right=df2, left_on='year',right_on='year')
        df_r = df_r.append(df_n)
    #escala logaritmica
    #df_r['oil'] = np.log10(df_r['oil'])
    #df_r['gold'] = np.log10(df_r['gold'])
    #df_r['copper'] = np.log10(df_r['copper'])
    #df_r['sp500'] = np.log10(df_r['sp500'])
    #Eliminando outliers por hiperinflacion
    #q1 = df_r['infl_cpi'].quantile(q=0.25)
    #q3 = df_r['infl_cpi'].quantile(q=0.75)
    #iqr = q3 - q1 
    #lower = q1 - 1.5 * iqr
    #min_v = df_r['infl_cpi'].min()
    #upper = q3 + 1.5 * iqr
    #df_r['infl_cpi'] = np.clip(df_r['infl_cpi'],min_v,upper)
    df_r = df_r.set_index('year')
    #elimina filas con datos faltantes en los extremos
    df_r = df_r.dropna()
    return df_r

# %%
df = preprocesar(df_wb,df_com)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2444 entries, 1983 to 2021
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   country      2444 non-null   object
#  1   iso          2444 non-null   object
#  2   trade        2444 non-null   float64
#  3   exports      2444 non-null   float64
#  4   imports      2444 non-null   float64
#  5   ggfce        2444 non-null   float64
#  6   gfcf         2444 non-null   float64
#  7   unempl       2444 non-null   float64
#  8   rgdp_growth  2444 non-null   float64
#  9   infl_cpi     2444 non-null   float64
#  10  oil          2444 non-null   float64
#  11  gold         2444 non-null   float64
#  12  copper       2444 non-null   float64
#  13  sp500        2444 non-null   float64
# dtypes: float64(12), object(2)
# memory usage: 286.4+ KB

# %%
df.describe().T
# Out:
#               count         mean          std          min          25%  \
# trade        2444.0    72.344116    49.169122     9.135846    41.999155
# exports      2444.0    35.783555    26.138226     4.990050    20.089363
# imports      2444.0    36.560562    23.606508     3.886755    21.672043
# ggfce        2444.0    16.137990     5.141125     0.911235    12.107257
# gfcf         2444.0    22.657086     5.669238     3.396226    19.149706
# unempl       2444.0     6.993838     4.025555     0.200000     4.000000
# rgdp_growth  2444.0     3.300628     3.655321   -17.944864     1.620492
# infl_cpi     2444.0    24.401148   306.043992    -4.478103     2.000118
# oil          2444.0    46.342523    25.213121     5.212236    22.794962
# gold         2444.0   759.505684   440.835124   154.823500   416.773776
# copper       2444.0  4342.676059  2110.620054  1951.648771  2545.072356
# sp500        2444.0  1593.592999   944.129572   363.590000   706.830000
#
#                      50%          75%           max
# trade          58.423119    84.386094    388.847728
# exports        28.305523    42.697135    212.117152
# imports        30.004589    42.869058    176.730577
# ggfce          16.435264    19.716854     27.993926
# gfcf           22.111505    25.406595     54.948270
# unempl          6.195000     9.000000     27.469999
# rgdp_growth     3.456450     5.200586     25.176245
# infl_cpi        4.059958     9.361443  11749.639632
# oil            44.378607    64.021950     95.311523
# gold          535.601622  1186.069383   1789.414970
# copper       3347.899152  6339.762495   9264.169006
# sp500        1677.160000  2221.610000   4239.200000

# %% [markdown]
# # Guardar

# %%
df.to_csv('../data/wb_dataset_prep.csv')

# %%
print(df_wb['iso'].unique())
# Out:
# ['DEU' 'AUS' 'AUT' 'BGD' 'BEL' 'BOL' 'BRA' 'CAN' 'CHL' 'CHN' 'COL' 'CRI'
#  'HRV' 'DNK' 'ECU' 'SLV' 'ESP' 'USA' 'EST' 'RUS' 'FIN' 'FRA' 'GRC' 'GTM'
#  'HND' 'HUN' 'IND' 'IDN' 'IRL' 'ISL' 'ISR' 'ITA' 'JPN' 'JOR' 'KEN' 'LTU'
#  'LUX' 'MYS' 'MLT' 'MAR' 'MEX' 'NGA' 'NOR' 'NLD' 'PAK' 'PAN' 'PRY' 'PER'
#  'POL' 'PRT' 'GBR' 'EGY' 'KOR' 'ROU' 'SWE' 'CHE' 'TUR' 'URY' 'VNM' 'NZL']

# %%
df_wb = df_wb.set_index('year')

# %%
#graficar(df[df.iso=='PER']['agriculture'],'Agricultura (% PBI)')

# %%
#graficar2(df_wb[df_wb.iso=='PER']['agriculture'],'Agricultura (% PBI)',df[df.iso=='PER']['agriculture'],'Agricultura (% PBI)')

# %%
graficar2(df_wb[df_wb.iso=='PER']['unempl'],'Tasa de Desempleo (% PEA)',df[df.iso=='PER']['unempl'],'Tasa de Desempleo (% PEA)')

# %%
df_p = pd.read_csv('../data/wb_dataset_prep.csv')
df_p.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2444 entries, 0 to 2443
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   year         2444 non-null   int64
#  1   country      2444 non-null   object
#  2   iso          2444 non-null   object
#  3   trade        2444 non-null   float64
#  4   exports      2444 non-null   float64
#  5   imports      2444 non-null   float64
#  6   ggfce        2444 non-null   float64
#  7   gfcf         2444 non-null   float64
#  8   unempl       2444 non-null   float64
#  9   rgdp_growth  2444 non-null   float64
#  10  infl_cpi     2444 non-null   float64
#  11  oil          2444 non-null   float64
#  12  gold         2444 non-null   float64
#  13  copper       2444 non-null   float64
#  14  sp500        2444 non-null   float64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 286.5+ KB

# %%
df_p.describe()
# Out:
#               year        trade      exports      imports        ggfce  \
# count  2444.000000  2444.000000  2444.000000  2444.000000  2444.000000
# mean   1999.717676    72.344116    35.783555    36.560562    16.137990
# std      13.541301    49.169122    26.138226    23.606508     5.141125
# min    1969.000000     9.135846     4.990050     3.886755     0.911235
# 25%    1989.000000    41.999155    20.089363    21.672043    12.107257
# 50%    2001.000000    58.423119    28.305523    30.004589    16.435264
# 75%    2011.000000    84.386094    42.697135    42.869058    19.716854
# max    2021.000000   388.847728   212.117152   176.730577    27.993926
#
#               gfcf       unempl  rgdp_growth      infl_cpi          oil  \
# count  2444.000000  2444.000000  2444.000000   2444.000000  2444.000000
# mean     22.657086     6.993838     3.300628     24.401148    46.342523
# std       5.669238     4.025555     3.655321    306.043992    25.213121
# min       3.396226     0.200000   -17.944864     -4.478103     5.212236
# 25%      19.149706     4.000000     1.620492      2.000118    22.794962
# 50%      22.111505     6.195000     3.456450      4.059958    44.378607
# 75%      25.406595     9.000000     5.200586      9.361443    64.021950
# max      54.948270    27.469999    25.176245  11749.639632    95.311523
#
#               gold       copper        sp500
# count  2444.000000  2444.000000  2444.000000
# mean    759.505684  4342.676059  1593.592999
# std     440.835124  2110.620054   944.129572
# min     154.823500  1951.648771   363.590000
# 25%     416.773776  2545.072356   706.830000
# 50%     535.601622  3347.899152  1677.160000
# 75%    1186.069383  6339.762495  2221.610000
# max    1789.414970  9264.169006  4239.200000

# %%
df_p.hist(bins=20,figsize=(10,12))
# Out:
# array([[<AxesSubplot:title={'center':'year'}>,
#         <AxesSubplot:title={'center':'trade'}>,
#         <AxesSubplot:title={'center':'exports'}>,
#         <AxesSubplot:title={'center':'imports'}>],
#        [<AxesSubplot:title={'center':'ggfce'}>,
#         <AxesSubplot:title={'center':'gfcf'}>,
#         <AxesSubplot:title={'center':'unempl'}>,
#         <AxesSubplot:title={'center':'rgdp_growth'}>],
#        [<AxesSubplot:title={'center':'infl_cpi'}>,
#         <AxesSubplot:title={'center':'oil'}>,
#         <AxesSubplot:title={'center':'gold'}>,
#         <AxesSubplot:title={'center':'copper'}>],
#        [<AxesSubplot:title={'center':'sp500'}>, <AxesSubplot:>,
#         <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
from wordcloud import WordCloud
from wordcloud import ImageColorGenerator
from wordcloud import STOPWORDS

# %%
#text = " ".join(i for i in df_p.iso)
iso = df_p['country'].value_counts().to_dict()

wordcloud = WordCloud(mode = "RGBA",max_words=60, background_color=None,width=900,height=600).generate_from_frequencies(iso)
plt.figure( figsize=(13,9))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
paises = df_p['country'].value_counts().sort_values(ascending=True)
labels = paises.index
cant = paises.values

fig,ax = plt.subplots(figsize=(8,15))
ax.barh(labels,cant)
ax.set_xlabel("Observaciones")
ax.set_ylabel("Países")
# Out:
# Text(0, 0.5, 'Países')
